# %% [markdown]
# ### __Notebook para testes de riscos não proporcionais__
#
# - Usamos distribuição Log-Normal aqui

# %%
source("/workspaces/estudo_de_adequabilidade_de_poder_de_teste/funcoes_final_nao_proporcionais.R")
# Out:
# Attaching package: ‘survival’
#
#
# The following object is masked from ‘package:Rlab’:
#
#     cancer
#
#
# Loading required package: ggpubr
#
#
# Attaching package: ‘survminer’
#
#
# The following object is masked from ‘package:survival’:
#
#     myeloma

# %%
### =========================================== APLICACAO ======================= ###
n <- 200
pi <- 0.5

distribuicao <- "log_normal"

parametro_falha_experimental <- 6
parametro_censura_experimental <- 6.74

parametro_falha_controle <- 6.50
parametro_censura_controle <- 7.24

## 2. distribuicao log-normal

# grupo experimental:
sdlog_falha_experimental <- 1
sdlog_censura_experimental <- sdlog_falha_experimental

# grupo controle
sdlog_falha_controle <- 2
sdlog_censura_controle <- sdlog_falha_controle


shape_falha_experimental_weibull <- 1
shape_falha_controle_weibull <- 1
shape_censura_experimental_weibull <- shape_falha_experimental_weibull
shape_censura_controle_weibull <- shape_falha_controle_weibull

# %%
dados <- exemplo(distribuicao, n, pi, 
                    parametro_falha_experimental, parametro_falha_controle, 
                    parametro_censura_experimental, parametro_censura_controle,
                    shape_falha_experimental_weibull, shape_censura_experimental_weibull, 
                    shape_falha_controle_weibull, shape_censura_controle_weibull, 
                    sdlog_falha_experimental, sdlog_censura_experimental, 
                    sdlog_falha_controle, sdlog_censura_controle)
# Out:
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 21.2%
# Grupo Controle     (B) - Censura Observada: 45.8%
# ...

# %%
curva <- survfit(Surv(z, delta) ~ grupo, data = dados)
ggsurvplot(curva, 
           fun = "cloglog",   # Aplica log(-log(S(t))) no eixo Y
           # Não usamos nenhum argumento de log para o eixo X
           ggtheme = theme_minimal(),
           title = "Gráfico Log(-Log(S(t))) vs Tempo (t)",
           xlab = "Tempo (t)", 
           ylab = "Log(-Log(Sobrevivência))")

ggsurvplot(
  curva,
  conf.int = FALSE,
  risk.table = FALSE,
  ggtheme = theme_minimal(),
  title = "Curva de Sobrevivência S(t)",
  xlab = "Tempo (t)",
  ylab = "S(t)"
)$plot
# Out:
# Ignoring unknown labels:
# • fill : "Strata"
# • linetype : "1"
# Ignoring unknown labels:
# • fill : "Strata"
# • linetype : "1"
# Ignoring unknown labels:
# • fill : "Strata"
# • linetype : "1"
# plot without title
# plot without title

# %%
simulacao_final(n_sim = 5, rho1 = 0, eta1 = 0, rho2 = 1, eta2 = 0, alpha = 0.05)
# Out:
# Simulação 1 de 5
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 33.3%
# Grupo Controle     (B) - Censura Observada: 48.3%
# ...
# Simulação 2 de 5
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 35.7%
# Grupo Controle     (B) - Censura Observada: 40.9%
# ...
# Simulação 3 de 5
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 37.3%
# Grupo Controle     (B) - Censura Observada: 42.9%
# ...
# Simulação 4 de 5
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 17.3%
# Grupo Controle     (B) - Censura Observada: 43.8%
# ...
# Simulação 5 de 5
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 15.4%
# Grupo Controle     (B) - Censura Observada: 37.5%
# ...
# plot without title

# %%
simulacao_amostral_empirica(n_sim = 200 ,ns =  seq(20, 500, by = 20), rho1 = 0, eta1 = 0,
                                        rho2 = 1, eta2 = 0, 
                                        alpha = 0.05)
# Out:
# Processando n = 20
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 46.2%
# Grupo Controle     (B) - Censura Observada: 71.4%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 14.3%
# Grupo Controle     (B) - Censura Observada: 50.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 20.0%
# Grupo Controle     (B) - Censura Observada: 10.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 11.1%
# Grupo Controle     (B) - Censura Observada: 18.2%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 30.0%
# Grupo Controle     (B) - Censura Observada: 20.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 18.2%
# Grupo Controle     (B) - Censura Observada: 33.3%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 28.6%
# Grupo Controle     (B) - Censura Observada: 50.0%
# ...
#
# ...

# %%
simulacao_amostral_empirica(n_sim = 200 ,ns =  seq(20, 500, by = 20), rho1 = 0, eta1 = 0,
                                        rho2 = 1, eta2 = 1, 
                                        alpha = 0.05)
# Out:
# Processando n = 20
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 37.5%
# Grupo Controle     (B) - Censura Observada: 25.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 50.0%
# Grupo Controle     (B) - Censura Observada: 30.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 22.2%
# Grupo Controle     (B) - Censura Observada: 45.5%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 28.6%
# Grupo Controle     (B) - Censura Observada: 53.8%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 28.6%
# Grupo Controle     (B) - Censura Observada: 46.2%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 37.5%
# Grupo Controle     (B) - Censura Observada: 25.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 0.0%
# Grupo Controle     (B) - Censura Observada: 42.9%
# ...
#
# ...

# %%
simulacao_amostral_empirica(n_sim = 200 ,ns =  seq(20, 500, by = 20), rho1 = 0, eta1 = 0,
                                        rho2 = 0, eta2 = 1, 
                                        alpha = 0.05)
# Out:
# Processando n = 20
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 14.3%
# Grupo Controle     (B) - Censura Observada: 30.8%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 0.0%
# Grupo Controle     (B) - Censura Observada: 41.7%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 23.1%
# Grupo Controle     (B) - Censura Observada: 71.4%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 45.5%
# Grupo Controle     (B) - Censura Observada: 33.3%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 54.5%
# Grupo Controle     (B) - Censura Observada: 44.4%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 35.7%
# Grupo Controle     (B) - Censura Observada: 50.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 35.7%
# Grupo Controle     (B) - Censura Observada: 33.3%
# ...
#
# ...

# %%
simulacao_amostral_empirica(n_sim = 200 ,ns =  seq(20, 500, by = 20), rho1 = 1, eta1 = 0,
                                        rho2 = 0, eta2 = 1, 
                                        alpha = 0.05)
# Out:
# Processando n = 20
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 20.0%
# Grupo Controle     (B) - Censura Observada: 20.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 36.4%
# Grupo Controle     (B) - Censura Observada: 44.4%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 20.0%
# Grupo Controle     (B) - Censura Observada: 30.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 33.3%
# Grupo Controle     (B) - Censura Observada: 80.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 20.0%
# Grupo Controle     (B) - Censura Observada: 33.3%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 36.4%
# Grupo Controle     (B) - Censura Observada: 33.3%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 9.1%
# Grupo Controle     (B) - Censura Observada: 44.4%
# ...
#
# ...

# %%
simulacao_amostral_empirica(n_sim = 200 ,ns =  seq(20, 500, by = 20), rho1 = 1, eta1 = 0,
                                        rho2 = 1, eta2 = 1, 
                                        alpha = 0.05)
# Out:
# Processando n = 20
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 37.5%
# Grupo Controle     (B) - Censura Observada: 25.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 55.6%
# Grupo Controle     (B) - Censura Observada: 36.4%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 12.5%
# Grupo Controle     (B) - Censura Observada: 41.7%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 33.3%
# Grupo Controle     (B) - Censura Observada: 62.5%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 27.3%
# Grupo Controle     (B) - Censura Observada: 55.6%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 37.5%
# Grupo Controle     (B) - Censura Observada: 41.7%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 40.0%
# Grupo Controle     (B) - Censura Observada: 30.0%
# ...
#
# ...

# %%
simulacao_amostral_empirica(n_sim = 200 ,ns =  seq(20, 500, by = 20), rho1 = 1, eta1 =1,
                                        rho2 = 0, eta2 = 1, 
                                        alpha = 0.05)
# Out:
# Processando n = 20
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 12.5%
# Grupo Controle     (B) - Censura Observada: 25.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 33.3%
# Grupo Controle     (B) - Censura Observada: 35.7%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 22.2%
# Grupo Controle     (B) - Censura Observada: 36.4%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 35.7%
# Grupo Controle     (B) - Censura Observada: 83.3%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 18.2%
# Grupo Controle     (B) - Censura Observada: 44.4%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 50.0%
# Grupo Controle     (B) - Censura Observada: 57.1%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 16.7%
# Grupo Controle     (B) - Censura Observada: 25.0%
# ...
#
# ...

# %%
simulacao_amostral_empirica(n_sim = 200 ,ns =  seq(20, 500, by = 20), rho1 = 1, eta1 = 1,
                                        rho2 = 1, eta2 = 0, 
                                        alpha = 0.05)
# Out:
# Processando n = 20
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 50.0%
# Grupo Controle     (B) - Censura Observada: 60.0%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 28.6%
# Grupo Controle     (B) - Censura Observada: 38.5%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 12.5%
# Grupo Controle     (B) - Censura Observada: 41.7%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 30.8%
# Grupo Controle     (B) - Censura Observada: 14.3%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 45.5%
# Grupo Controle     (B) - Censura Observada: 55.6%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 27.3%
# Grupo Controle     (B) - Censura Observada: 55.6%
# ...
#
# === Relatório da Simulação ===
# Grupo Experimental (A) - Censura Observada: 33.3%
# Grupo Controle     (B) - Censura Observada: 54.5%
# ...
#
# ...
